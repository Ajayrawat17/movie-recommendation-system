# %%
import pandas as pd

# %%
import numpy as np

# %%
movies = pd.read_csv(r"C:\Users\HP\Desktop\tmdb_5000_movies.csv")

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %%
credits = pd.read_csv(r"C:\Users\HP\Desktop\tmdb_5000_credits.csv")

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
movies = movies.merge(credits,on='title')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  ... runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...   165.0
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count movie_id  \
# 0                                    Avatar          7.2      11800    19995
# 1  Pirates of the Caribbean: At World's End          6.9       4500      285
# 2                                   Spectre          6.3       4466   206647
# 3                     The Dark Knight Rises          7.6       9106    49026
# 4                               John Carter          6.1       2124    49529
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 23 columns]

# %%
movies = movies[['movie_id','title','overview','genres','keywords','cast','crew']]

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
import ast

# %%
def convert(text):
    L = []
    for i in ast.literal_eval(text):
        L.append(i['name']) 
    return L

# %%
movies.dropna(inplace=True)

# %%
def convert(text):
    if isinstance(text, list):
        return text
    else:
        genres_list = text.strip("[]").replace("'", "").split(", ")
        return genres_list

# %%
movies['genres'] = movies['genres'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
def convert(text):
    if isinstance(text, list):
        return text
    else:
        keywords_list = text.strip("[]").replace("'", "").split(", ")
        return keywords_list

# %%
movies['keywords'] = movies['keywords'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
import ast
ast.literal_eval('[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]')
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
def convert3(text):
    L = []
    counter = 0
    for i in ast.literal_eval(text):
        if counter < 3:
            L.append(i['name'])
        counter+=1
    return L

# %%
movies['cast'] = movies['cast'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
movies['cast'] = movies['cast'].apply(lambda x:x[0:3])

# %%
def fetch_director(text):
    L = []
    for i in ast.literal_eval(text):
        if i['job'] == 'Director':
            L.append(i['name'])
    return L

# %%
movies['crew'] = movies['crew'].apply(fetch_director)

# %%
movies.sample(5)
# Out:
#       movie_id                   title  \
# 2951     11109              Vera Drake
# 3533    138697                 Don Jon
# 360       2253                Valkyrie
# 1410      2288                  Closer
# 157     147441  Exodus: Gods and Kings
#
#                                                overview  \
# 2951  Abortionist Vera Drake finds her beliefs and p...
# 3533  A New Jersey guy dedicated to his family, frie...
# 360   Wounded in Africa during World War II, Nazi Co...
# 1410  A witty, romantic, and very dangerous love sto...
# 157   The defiant leader Moses rises up against the ...
#
#                                                  genres  \
# 2951  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# 3533  [{"id": 10749, "name": "Romance"}, {"id": 35, ...
# 360   [{"id": 18, "name": "Drama"}, {"id": 53, "name...
# 1410  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 157   [{"id": 12, "name": "Adventure"}, {"id": 18, "...
#
#                                                keywords  \
# 2951  [{"id": 392, "name": "england"}, {"id": 2784, ...
# 3533  [{"id": 445, "name": "pornography"}, {"id": 57...
# 360   [{"id": 220, "name": "berlin"}, {"id": 236, "n...
# 1410  [{"id": 494, "name": "father son relationship"...
# 157   [{"id": 488, "name": "moses"}, {"id": 3036, "n...
#
#                                                    cast  \
# 2951  [{"cast_id": 2, "character": "Vera Drake", "cr...
# 3533  [{"cast_id": 8, "character": "Jon Martello, Jr."]
# 360   [{"cast_id": 8, "character": "Claus Schenk Gra...
# 1410  [{"cast_id": 4, "character": "Anna Cameron", "...
# 157   [{"cast_id": 1, "character": "Moses", "credit_...
#
#                         crew
# 2951            [Mike Leigh]
# 3533  [Joseph Gordon-Levitt]
# 360           [Bryan Singer]
# 1410          [Mike Nichols]
# 157           [Ridley Scott]

# %%
def collapse(L):
    L1 = []
    for i in L:
        L1.append(i.replace(" ",""))
    return L1

# %%
movies['cast'] = movies['cast'].apply(collapse)
movies['crew'] = movies['crew'].apply(collapse)
movies['genres'] = movies['genres'].apply(collapse)
movies['keywords'] = movies['keywords'].apply(collapse)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id":28, "name":"Action"}, {"id":12, "name":...
# 1  [{"id":12, "name":"Adventure"}, {"id":14, "nam...
# 2  [{"id":28, "name":"Action"}, {"id":12, "name":...
# 3  [{"id":28, "name":"Action"}, {"id":80, "name":...
# 4  [{"id":28, "name":"Action"}, {"id":12, "name":...
#
#                                             keywords  \
# 0  [{"id":1463, "name":"cultureclash"}, {"id":296...
# 1  [{"id":270, "name":"ocean"}, {"id":726, "name"...
# 2  [{"id":470, "name":"spy"}, {"id":818, "name":"...
# 3  [{"id":849, "name":"dccomics"}, {"id":853, "na...
# 4  [{"id":818, "name":"basedonnovel"}, {"id":839,...
#
#                                                 cast                crew
# 0  [{"cast_id":242, "character":"JakeSully", "cre...      [JamesCameron]
# 1  [{"cast_id":4, "character":"CaptainJackSparrow...     [GoreVerbinski]
# 2  [{"cast_id":1, "character":"JamesBond", "credi...         [SamMendes]
# 3  [{"cast_id":2, "character":"BruceWayne/Batman"...  [ChristopherNolan]
# 4  [{"cast_id":5, "character":"JohnCarter", "cred...     [AndrewStanton]

# %%
movies['overview'] = movies['overview'].apply(lambda x:x.split())

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

# %%
new = movies.drop(columns=['overview','genres','keywords','cast','crew'])

# %%
new['tags'] = new['tags'].apply(lambda x: " ".join(x))
new.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
vector = cv.fit_transform(new['tags']).toarray()
vector.shape
# Out:
# (4806, 5000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.92615   , 0.83243478, ..., 0.7846835 , 0.02346132,
#         0.59266882],
#        [0.92615   , 1.        , 0.82540289, ..., 0.77525611, 0.02276126,
#         0.58696316],
#        [0.83243478, 0.82540289, 1.        , ..., 0.70349001, 0.03852809,
#         0.53733084],
#        ...,
#        [0.7846835 , 0.77525611, 0.70349001, ..., 1.        , 0.07349388,
#         0.53182934],
#        [0.02346132, 0.02276126, 0.03852809, ..., 0.07349388, 1.        ,
#         0.09179335],
#        [0.59266882, 0.58696316, 0.53733084, ..., 0.53182934, 0.09179335,
#         1.        ]])

# %%
new[new['title'] == 'The Lego Movie'].index[0]
# Out:
# 744

# %%
def recommend(movie):
    index = new[new['title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:6]:
        print(new.iloc[i[0]].title)

# %%
movies.head(25)
# Out:
#     movie_id                                        title  \
# 0      19995                                       Avatar
# 1        285     Pirates of the Caribbean: At World's End
# 2     206647                                      Spectre
# 3      49026                        The Dark Knight Rises
# 4      49529                                  John Carter
# 5        559                                 Spider-Man 3
# 6      38757                                      Tangled
# 7      99861                      Avengers: Age of Ultron
# 8        767       Harry Potter and the Half-Blood Prince
# 9     209112           Batman v Superman: Dawn of Justice
# 10      1452                             Superman Returns
# 11     10764                            Quantum of Solace
# 12        58   Pirates of the Caribbean: Dead Man's Chest
# 13     57201                              The Lone Ranger
# 14     49521                                 Man of Steel
# 15      2454     The Chronicles of Narnia: Prince Caspian
# 16     24428                                 The Avengers
# 17      1865  Pirates of the Caribbean: On Stranger Tides
# 18     41154                               Men in Black 3
# 19    122917    The Hobbit: The Battle of the Five Armies
# 20      1930                       The Amazing Spider-Man
# 21     20662                                   Robin Hood
# 22     57158          The Hobbit: The Desolation of Smaug
# 23      2268                           The Golden Compass
# 24       254                                    King Kong
#
#                                              overview  \
# 0   [In, the, 22nd, century,, a, paraplegic, Marin...
# 1   [Captain, Barbossa,, long, believed, to, be, d...
# 2   [A, cryptic, message, from, Bond’s, past, send...
# 3   [Following, the, death, of, District, Attorney...
# 4   [John, Carter, is, a, war-weary,, former, mili...
# 5   [The, seemingly, invincible, Spider-Man, goes,...
# 6   [When, the, kingdom's, most, wanted-and, most,...
# 7   [When, Tony, Stark, tries, to, jumpstart, a, d...
# 8   [As, Harry, begins, his, sixth, year, at, Hogw...
# 9   [Fearing, the, actions, of, a, god-like, Super...
# 10  [Superman, returns, to, discover, his, 5-year,...
# 11  [Quantum, of, Solace, continues, the, adventur...
# 12  [Captain, Jack, Sparrow, works, his, way, out,...
# 13  [The, Texas, Rangers, chase, down, a, gang, of...
# 14  [A, young, boy, learns, that, he, has, extraor...
# 15  [One, year, after, their, incredible, adventur...
# 16  [When, an, unexpected, enemy, emerges, and, th...
# 17  [Captain, Jack, Sparrow, crosses, paths, with,...
# 18  [Agents, J, (Will, Smith), and, K, (Tommy, Lee...
# 19  [Immediately, after, the, events, of, The, Des...
# 20  [Peter, Parker, is, an, outcast, high, schoole...
# 21  [When, soldier, Robin, happens, upon, the, dyi...
# 22  [The, Dwarves,, Bilbo, and, Gandalf, have, suc...
# 23  [After, overhearing, a, shocking, secret,, pre...
# 24  [In, 1933, New, York,, an, overly, ambitious, ...
#
#                                                genres  \
# 0   [{"id":28, "name":"Action"}, {"id":12, "name":...
# 1   [{"id":12, "name":"Adventure"}, {"id":14, "nam...
# 2   [{"id":28, "name":"Action"}, {"id":12, "name":...
# 3   [{"id":28, "name":"Action"}, {"id":80, "name":...
# 4   [{"id":28, "name":"Action"}, {"id":12, "name":...
# 5   [{"id":14, "name":"Fantasy"}, {"id":28, "name"...
# 6   [{"id":16, "name":"Animation"}, {"id":10751, "...
# 7   [{"id":28, "name":"Action"}, {"id":12, "name":...
# 8   [{"id":12, "name":"Adventure"}, {"id":14, "nam...
# 9   [{"id":28, "name":"Action"}, {"id":12, "name":...
# 10  [{"id":12, "name":"Adventure"}, {"id":14, "nam...
# 11  [{"id":12, "name":"Adventure"}, {"id":28, "nam...
# 12  [{"id":12, "name":"Adventure"}, {"id":14, "nam...
# 13  [{"id":28, "name":"Action"}, {"id":12, "name":...
# 14  [{"id":28, "name":"Action"}, {"id":12, "name":...
# 15  [{"id":12, "name":"Adventure"}, {"id":10751, "...
# 16  [{"id":878, "name":"ScienceFiction"}, {"id":28...
# 17  [{"id":12, "name":"Adventure"}, {"id":28, "nam...
# 18  [{"id":28, "name":"Action"}, {"id":35, "name":...
# 19  [{"id":28, "name":"Action"}, {"id":12, "name":...
# 20  [{"id":28, "name":"Action"}, {"id":12, "name":...
# 21  [{"id":28, "name":"Action"}, {"id":12, "name":...
# 22  [{"id":12, "name":"Adventure"}, {"id":14, "nam...
# 23  [{"id":12, "name":"Adventure"}, {"id":14, "nam...
# 24  [{"id":12, "name":"Adventure"}, {"id":18, "nam...
#
#                                              keywords  \
# 0   [{"id":1463, "name":"cultureclash"}, {"id":296...
# 1   [{"id":270, "name":"ocean"}, {"id":726, "name"...
# 2   [{"id":470, "name":"spy"}, {"id":818, "name":"...
# 3   [{"id":849, "name":"dccomics"}, {"id":853, "na...
# 4   [{"id":818, "name":"basedonnovel"}, {"id":839,...
# 5   [{"id":851, "name":"dualidentity"}, {"id":1453...
# 6   [{"id":1562, "name":"hostage"}, {"id":2343, "n...
# 7   [{"id":8828, "name":"marvelcomic"}, {"id":9663...
# 8   [{"id":616, "name":"witch"}, {"id":2343, "name...
# 9   [{"id":849, "name":"dccomics"}, {"id":7002, "n...
# 10  [{"id":83, "name":"savingtheworld"}, {"id":849...
# 11  [{"id":627, "name":"killing"}, {"id":1568, "na...
# 12  [{"id":616, "name":"witch"}, {"id":663, "name"...
# 13  [{"id":1556, "name":"texas"}, {"id":2673, "nam...
# 14  [{"id":83, "name":"savingtheworld"}, {"id":849...
# 15  [{"id":818, "name":"basedonnovel"}, {"id":855,...
# 16  [{"id":242, "name":"newyork"}, {"id":5539, "na...
# 17  [{"id":658, "name":"sea"}, {"id":1316, "name":...
# 18  [{"id":4379, "name":"timetravel"}, {"id":5455,...
# 19  [{"id":417, "name":"corruption"}, {"id":603, "...
# 20  [{"id":1872, "name":"lossoffather"}, {"id":700...
# 21  [{"id":4147, "name":"robinhood"}, {"id":4393, ...
# 22  [{"id":603, "name":"elves"}, {"id":604, "name"...
# 23  [{"id":392, "name":"england"}, {"id":1461, "na...
# 24  [{"id":774, "name":"filmbusiness"}, {"id":776,...
#
#                                                  cast  \
# 0   [{"cast_id":242, "character":"JakeSully", "cre...
# 1   [{"cast_id":4, "character":"CaptainJackSparrow...
# 2   [{"cast_id":1, "character":"JamesBond", "credi...
# 3   [{"cast_id":2, "character":"BruceWayne/Batman"...
# 4   [{"cast_id":5, "character":"JohnCarter", "cred...
# 5   [{"cast_id":30, "character":"PeterParker/Spide...
# 6   [{"cast_id":34, "character":"FlynnRider(voice)...
# 7   [{"cast_id":76, "character":"TonyStark/IronMan...
# 8   [{"cast_id":3, "character":"HarryPotter", "cre...
# 9   [{"cast_id":18, "character":"BruceWayne/Batman...
# 10  [{"cast_id":3, "character":"Superman/ClarkKent...
# 11  [{"cast_id":1, "character":"JamesBond", "credi...
# 12  [{"cast_id":37, "character":"CaptainJackSparro...
# 13  [{"cast_id":4, "character":"Tonto", "credit_id...
# 14  [{"cast_id":2, "character":"ClarkKent/Kal-El",...
# 15  [{"cast_id":1, "character":"PrinceCaspian", "c...
# 16  [{"cast_id":46, "character":"TonyStark/IronMan...
# 17  [{"cast_id":15, "character":"CaptainJackSparro...
# 18  [{"cast_id":4, "character":"AgentJ", "credit_i...
# 19  [{"cast_id":10, "character":"BilboBaggins", "c...
# 20  [{"cast_id":56, "character":"PeterParker/Spide...
# 21  [{"cast_id":1, "character":"RobinLongstride", ...
# 22  [{"cast_id":3, "character":"BilboBaggins", "cr...
# 23  [{"cast_id":43, "character":"LyraBelacqua", "c...
# 24  [{"cast_id":5, "character":"AnnDarrow", "credi...
#
#                           crew  \
# 0               [JamesCameron]
# 1              [GoreVerbinski]
# 2                  [SamMendes]
# 3           [ChristopherNolan]
# 4              [AndrewStanton]
# 5                   [SamRaimi]
# 6   [ByronHoward, NathanGreno]
# 7                 [JossWhedon]
# 8                 [DavidYates]
# 9                 [ZackSnyder]
# 10               [BryanSinger]
# 11               [MarcForster]
# 12             [GoreVerbinski]
# 13             [GoreVerbinski]
# 14                [ZackSnyder]
# 15             [AndrewAdamson]
# 16                [JossWhedon]
# 17               [RobMarshall]
# 18           [BarrySonnenfeld]
# 19              [PeterJackson]
# 20                  [MarcWebb]
# 21               [RidleyScott]
# 22              [PeterJackson]
# 23                [ChrisWeitz]
# 24              [PeterJackson]
#
#                                                  tags
# 0   [In, the, 22nd, century,, a, paraplegic, Marin...
# 1   [Captain, Barbossa,, long, believed, to, be, d...
# 2   [A, cryptic, message, from, Bond’s, past, send...
# 3   [Following, the, death, of, District, Attorney...
# 4   [John, Carter, is, a, war-weary,, former, mili...
# 5   [The, seemingly, invincible, Spider-Man, goes,...
# 6   [When, the, kingdom's, most, wanted-and, most,...
# 7   [When, Tony, Stark, tries, to, jumpstart, a, d...
# 8   [As, Harry, begins, his, sixth, year, at, Hogw...
# 9   [Fearing, the, actions, of, a, god-like, Super...
# 10  [Superman, returns, to, discover, his, 5-year,...
# 11  [Quantum, of, Solace, continues, the, adventur...
# 12  [Captain, Jack, Sparrow, works, his, way, out,...
# 13  [The, Texas, Rangers, chase, down, a, gang, of...
# 14  [A, young, boy, learns, that, he, has, extraor...
# 15  [One, year, after, their, incredible, adventur...
# 16  [When, an, unexpected, enemy, emerges, and, th...
# 17  [Captain, Jack, Sparrow, crosses, paths, with,...
# 18  [Agents, J, (Will, Smith), and, K, (Tommy, Lee...
# 19  [Immediately, after, the, events, of, The, Des...
# 20  [Peter, Parker, is, an, outcast, high, schoole...
# 21  [When, soldier, Robin, happens, upon, the, dyi...
# 22  [The, Dwarves,, Bilbo, and, Gandalf, have, suc...
# 23  [After, overhearing, a, shocking, secret,, pre...
# 24  [In, 1933, New, York,, an, overly, ambitious, ...

# %%
recommend('Pirates of the Caribbean: At World's End')
# Out:
#   Cell In[47], line 1
#     recommend('Pirates of the Caribbean: At World's End')
#                                                        ^
# SyntaxError: unterminated string literal (detected at line 1)
